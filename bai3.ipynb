# %%
from PIL import Image
from imgtools import *

# %%
# Đường dẫn ảnh
my_path = r'C:\Users\dangminhvu\Pictures/abc.PNG'

# %%
# Đọc ảnh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170>

# %%
print(img.size)
# Out:
# (297, 170)

# %%
new_size =(1000,1000)
new_image =img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x29>
